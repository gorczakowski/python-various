# %% [markdown]
# ### Simple scraping project
#
# This is a scraper written in Python using Beautiful Soup and Requests modules.
# It retrieves the pricing information from the website [kb.pl](https://kb.pl/) about various construction costs (materials and labor).
#
# - Most datapoints consist of 3 prices: low / medium / high.
# - Pricing info only for Poland, can vary depending on specific region (this can be controlled by providing session IDs)
#
# Let's start by checking the robots.txt:

# %%
import requests

robots = requests.get('https://kb.pl/robots.txt')
print(robots.text)
# Out:
# User-agent: *
# Disallow: /admin
# Disallow: /captcha/
#
# User-agent: bingbot
# Crawl-delay: 30
#
# Sitemap: https://kb.pl/sitemap.xml

# %% [markdown]
# The site only restricts the `/admin` and `/captcha/` directories, which we don't scrape - so it's all ok.
#
# Now let me demonstrate the scraper in action by retrieving data from a single url.

# %%
from scrape_kbpl import *

url = 'https://kb.pl/budowa/parterowy-bez-piwnicy/tynki-i-gips/'

single_data = scrape_single(url)

single_data
# Out:
# [('Tynkowanie - materiały gipsowy', 17.49),
#  ('Tynkowanie - materiały gipsowy', 19.77),
#  ('Tynkowanie - materiały gipsowy', 25.06),
#  ('Tynkowanie - materiały cementowo-wapienny', 20.41),
#  ('Tynkowanie - materiały cementowo-wapienny', 22.75),
#  ('Tynkowanie - materiały cementowo-wapienny', 26.48),
#  ('Tynkowanie - robocizna gipsowy', 19.06),
#  ('Tynkowanie - robocizna gipsowy', 25.1),
#  ('Tynkowanie - robocizna gipsowy', 31.89),
#  ('Tynkowanie - robocizna cementowo-wapienny', 17.74),
#  ('Tynkowanie - robocizna cementowo-wapienny', 25.0),
#  ('Tynkowanie - robocizna cementowo-wapienny', 31.11),
#  ('Gładź gipsowa',),
#  ('Robocizna - gipsowanie', 18.38),
#  ('Robocizna - gipsowanie', 24.35),
#  ('Robocizna - gipsowanie', 43.39)]

# %% [markdown]
# The function above returned the data as a list of tuples. There is another function that groups the rows by their names. Grouped data can be saved to a file and imported into Excel for further analysis.

# %%
group_by_name(single_data)

# data_to_csv(single_data) # saves the data to dump.txt file in the current directory
# Out:
# [('Tynkowanie - materiały gipsowy', 17.49, 19.77, 25.06),
#  ('Tynkowanie - materiały cementowo-wapienny', 20.41, 22.75, 26.48),
#  ('Tynkowanie - robocizna gipsowy', 19.06, 25.1, 31.89),
#  ('Tynkowanie - robocizna cementowo-wapienny', 17.74, 25.0, 31.11),
#  ('Gładź gipsowa',),
#  ('Robocizna - gipsowanie', 18.38, 24.35, 43.39)]

# %% [markdown]
# And now onto scraping the entire site:

# %%
data = scrape_all()

# %%
data
# Out:
# [('Fundamenty - potrzebne materiały', 110.48),
#  ('Fundamenty - potrzebne materiały', 127.48),
#  ('Fundamenty - potrzebne materiały', 166.84),
#  ('Robocizna - wykonanie fundamentów', 76.18),
#  ('Robocizna - wykonanie fundamentów', 80.72),
#  ('Robocizna - wykonanie fundamentów', 92.7),
#  ('Ściany fundamentowe piwnicy - materiały', 53.32),
#  ('Ściany fundamentowe piwnicy - materiały', 70.49),
#  ('Ściany fundamentowe piwnicy - materiały', 97.49),
#  ('Robocizna - wykonanie ścian fundamentowych', 35.56),
#  ('Robocizna - wykonanie ścian fundamentowych', 52.27),
#  ('Robocizna - wykonanie ścian fundamentowych', 97.04),
#  ('Izolacja ścian piwnicy - materiały', 60.9),
#  ('Izolacja ścian piwnicy - materiały', 86.26),
#  ('Izolacja ścian piwnicy - materiały', 111.06),
#  ('Robocizna - izolacja ścian piwnicy', 43.62),
#  ('Robocizna - izolacja ścian piwnicy', 65.12),
#  ('Robocizna - izolacja ścian piwnicy', 116.09),
#  ('Ściany nośne - materiały beton komórkowy Ytong Energo+ 36,5 cm', 108.68),
#  ('Ściany nośne - materiały beton komórkowy Ytong Energo+ 36,5 cm', 123.0),
#  ('Ściany nośne - materiały beton komórkowy Ytong Energo+ 36,5 cm', 178.34),
#  ('Ściany nośne - materiały beton komórkowy H+H 24', 46.14),
#  ('Ściany nośne - materiały beton komórkowy H+H 24', 64.44),
#  ('Ściany nośne - materiały beton komórkowy H+H 24', 92.44),
#  ('Robocizna - wykonanie ścian nośnych beton komórkowy Ytong Energo+ 36,5 cm',
#   46.55),
#  ('Robocizna - wykonanie ścian nośnych beton komórkowy Ytong Energo+ 36,5 cm',
#   66.62),
#  ('Robocizna - wykonanie ścian nośnych beton komórkowy Ytong Energo+ 36,5 cm',
#   118.75),
#  ('Robocizna - wykonanie ścian nośnych beton komórkowy', 43.72),
#  ('Robocizna - wykonanie ścian nośnych beton komórkowy', 63.99),
#  ('Robocizna - wykonanie ścian nośnych beton komórkowy', 116.35),
#  ('Ściany działowe - materiały ceramiczne', 37.3),
#  ('Ściany działowe - materiały ceramiczne', 44.79),
#  ('Ściany działowe - materiały ceramiczne', 68.95),
#  ('Ściany działowe - materiały beton komórkowy', 25.66),
#  ('Ściany działowe - materiały beton komórkowy', 31.76),
#  ('Ściany działowe - materiały beton komórkowy', 38.71),
#  ('Robocizna - wykonanie ścian działowych ceramiczne', 29.16),
#  ('Robocizna - wykonanie ścian działowych ceramiczne', 39.3),
#  ('Robocizna - wykonanie ścian działowych ceramiczne', 63.39),
#  ('Robocizna - wykonanie ścian działowych beton komórkowy', 34.13),
#  ('Robocizna - wykonanie ścian działowych beton komórkowy', 36.65),
#  ('Robocizna - wykonanie ścian działowych beton komórkowy', 66.29),
#  ('Kominy wentylacyjne + szachty', 256.18),
#  ('Kominy wentylacyjne + szachty', 323.29),
#  ('Kominy wentylacyjne + szachty', 474.83),
#  ('Kominy dymowe', 3889.02),
#  ('Kominy dymowe', 4273.25),
#  ('Kominy dymowe', 4866.62),
#  ('Wykończenie kominów', 1135.35),
#  ('Wykończenie kominów', 1727.83),
#  ('Wykończenie kominów', 3091.26),
#  ('Schody żelbetowe z piwnicy na parter (materiał + robocizna)', 275.84),
#  ('Schody żelbetowe z piwnicy na parter (materiał + robocizna)', 363.38),
#  ('Schody żelbetowe z piwnicy na parter (materiał + robocizna)', 587.57),
#  ('Schody prefabrykowane z wykończeniem z piwnicy na parter schody stalowe',
#   1859.44),
#  ('Schody prefabrykowane z wykończeniem z piwnicy na parter schody stalowe',
#   2307.24),
#  ('Schody prefabrykowane z wykończeniem z piwnicy na parter schody stalowe',
#   3232.3),
#  ('Schody prefabrykowane z wykończeniem z piwnicy na parter schody drewniane',
#   2545.26),
#  ('Schody prefabrykowane z wykończeniem z piwnicy na parter schody drewniane',
#   2742.88),
#  ('Schody prefabrykowane z wykończeniem z piwnicy na parter schody drewniane',
#   3813.48),
#  ('Schody żelbetowe z parteru na piętro (materiały+robocizna)', 275.84),
#  ('Schody żelbetowe z parteru na piętro (materiały+robocizna)', 363.38),
#  ('Schody żelbetowe z parteru na piętro (materiały+robocizna)', 587.57),
#  ('Schody prefabrykowane z wykończeniem z parteru na piętro schody stalowe',
#   1859.44),
#  ('Schody prefabrykowane z wykończeniem z parteru na piętro schody stalowe',
#   2307.24),
#  ('Schody prefabrykowane z wykończeniem z parteru na piętro schody stalowe',
#   3232.3),
#  ('Schody prefabrykowane z wykończeniem z parteru na piętro schody drewniane',
#   2545.26),
#  ('Schody prefabrykowane z wykończeniem z parteru na piętro schody drewniane',
#   2742.88),
#  ('Schody prefabrykowane z wykończeniem z parteru na piętro schody drewniane',
#   3813.48),
#  ('I strop - nad piwnicą - niezbędne materiały teriva prefabrykowany', 374.11),
#  ('I strop - nad piwnicą - niezbędne materiały teriva prefabrykowany', 402.33),
#  ('I strop - nad piwnicą - niezbędne materiały teriva prefabrykowany', 498.57),
#  ('I strop - nad piwnicą - niezbędne materiały wylewany żelbetowy', 358.83),
#  ('I strop - nad piwnicą - niezbędne materiały wylewany żelbetowy', 394.02),
#  ('I strop - nad piwnicą - niezbędne materiały wylewany żelbetowy', 444.7),
#  ('Robocizna - I strop nad piwnicą teriva prefabrykowany', 42.38),
#  ('Robocizna - I strop nad piwnicą teriva prefabrykowany', 61.03),
#  ('Robocizna - I strop nad piwnicą teriva prefabrykowany', 121.89),
#  ('Robocizna - I strop nad piwnicą wylewany żelbetowy', 85.61),
#  ('Robocizna - I strop nad piwnicą wylewany żelbetowy', 122.27),
#  ('Robocizna - I strop nad piwnicą wylewany żelbetowy', 236.46),
#  ('II strop - nad parterem - niezbędne materiały teriva prefabrykowany',
#   374.11),
#  ('II strop - nad parterem - niezbędne materiały teriva prefabrykowany',
#   402.33),
#  ('II strop - nad parterem - niezbędne materiały teriva prefabrykowany',
#   498.57),
#  ('II strop - nad parterem - niezbędne materiały wylewany żelbetowy', 358.83),
#  ('II strop - nad parterem - niezbędne materiały wylewany żelbetowy', 394.02),
#  ('II strop - nad parterem - niezbędne materiały wylewany żelbetowy', 444.7),
#  ('Robocizna - II strop nad parterem teriva prefabrykowany', 42.38),
#  ('Robocizna - II strop nad parterem teriva prefabrykowany', 61.03),
#  ('Robocizna - II strop nad parterem teriva prefabrykowany', 121.89),
#  ('Robocizna - II strop nad parterem wylewany żelbetowy', 85.61),
#  ('Robocizna - II strop nad parterem wylewany żelbetowy', 122.27),
#  ('Robocizna - II strop nad parterem wylewany żelbetowy', 236.46),
#  ('III strop - nad piętrem - niezbędne materiały drewniany', 279.53),
#  ('III strop - nad piętrem - niezbędne materiały drewniany', 323.3),
#  ('III strop - nad piętrem - niezbędne materiały drewniany', 400.28),
#  ('III strop - nad piętrem - niezbędne materiały prefabrykowany teriva',
#   377.31),
#  ('III strop - nad piętrem - niezbędne materiały prefabrykowany teriva',
#   415.53),
#  ('III strop - nad piętrem - niezbędne materiały prefabrykowany teriva',
#   478.27),
#  ('Robocizna - III strop nad piętrem drewniany', 28.82),
#  ('Robocizna - III strop nad piętrem drewniany', 44.02),
#  ('Robocizna - III strop nad piętrem drewniany', 81.4),
#  ('Robocizna - III strop nad piętrem prefabrykowany teriva', 43.98),
#  ('Robocizna - III strop nad piętrem prefabrykowany teriva', 61.82),
#  ('Robocizna - III strop nad piętrem prefabrykowany teriva', 121.08),
#  ('Płyta balkonowa z robocizną', 171.57),
#  ('Płyta balkonowa z robocizną', 220.86),
#  ('Płyta balkonowa z robocizną', 345.49),
#  ('Elewacja i izolacja - materiały', 79.45),
#  ('Elewacja i izolacja - materiały', 101.11),
#  ('Elewacja i izolacja - materiały', 120.61),
#  ('Elewacja i izolacja - robocizna', 39.58),
#  ('Elewacja i izolacja - robocizna', 48.38),
#  ('Elewacja i izolacja - robocizna', 63.14),
#  ('Posadzka na balkonie - materał', 51.61),
#  ('Posadzka na balkonie - materał', 62.01),
#  ('Posadzka na balkonie - materał', 76.82),
#  ('Posadzka na balkonie  - robocizna', 49.21),
#  ('Posadzka na balkonie  - robocizna', 72.16),
#  ('Posadzka na balkonie  - robocizna', 141.49),
#  ('Balustrada stalowa', 570.69),
#  ('Balustrada stalowa', 618.99),
#  ('Balustrada stalowa', 762.19),
#  ('Elewacja - komplet materiałów styropian', 105.94),
#  ('Elewacja - komplet materiałów styropian', 131.73),
#  ('Elewacja - komplet materiałów styropian', 161.6),
#  ('Elewacja - komplet materiałów wełna mineralna', 142.64),
#  ('Elewacja - komplet materiałów wełna mineralna', 177.52),
#  ('Elewacja - komplet materiałów wełna mineralna', 209.63),
#  ('Elewacja - robocizna za wykonanie elewacji styropian', 71.29),
#  ('Elewacja - robocizna za wykonanie elewacji styropian', 83.38),
#  ('Elewacja - robocizna za wykonanie elewacji styropian', 103.71),
#  ('Elewacja - robocizna za wykonanie elewacji wełna mineralna', 81.7),
#  ('Elewacja - robocizna za wykonanie elewacji wełna mineralna', 92.3),
#  ('Elewacja - robocizna za wykonanie elewacji wełna mineralna', 113.19),
#  ('Więźba dachowa - materiały', 61.22),
#  ('Więźba dachowa - materiały', 75.56),
#  ('Więźba dachowa - materiały', 112.61),
#  ('Robocizna - wykonanie więźby dachowej', 31.65),
#  ('Robocizna - wykonanie więźby dachowej', 46.29),
#  ('Robocizna - wykonanie więźby dachowej', 78.42),
#  ('Poszycie dachu - materiały membrana', 3.82),
#  ('Poszycie dachu - materiały membrana', 4.39),
#  ('Poszycie dachu - materiały membrana', 5.45),
#  ('Poszycie dachu - materiały papa na deskowaniu', 39.72),
#  ('Poszycie dachu - materiały papa na deskowaniu', 49.45),
#  ('Poszycie dachu - materiały papa na deskowaniu', 69.18),
#  ('Robocizna - wykonanie poszycia dachu membrana', 8.7),
#  ('Robocizna - wykonanie poszycia dachu membrana', 12.92),
#  ('Robocizna - wykonanie poszycia dachu membrana', 23.0),
#  ('Robocizna - wykonanie poszycia dachu papa na deskowaniu', 19.97),
#  ('Robocizna - wykonanie poszycia dachu papa na deskowaniu', 29.66),
#  ('Robocizna - wykonanie poszycia dachu papa na deskowaniu', 47.89),
#  ('Pokrycie zewnętrzne dachu - materiały blachodachówka', 51.4),
#  ('Pokrycie zewnętrzne dachu - materiały blachodachówka', 58.02),
#  ('Pokrycie zewnętrzne dachu - materiały blachodachówka', 73.26),
#  ('Pokrycie zewnętrzne dachu - materiały dachówka ceramiczna', 69.34),
#  ('Pokrycie zewnętrzne dachu - materiały dachówka ceramiczna', 87.21),
#  ('Pokrycie zewnętrzne dachu - materiały dachówka ceramiczna', 103.63),
#  ('Robocizna - pokrycie zewnętrzne dachu blachodachówka', 43.32),
#  ('Robocizna - pokrycie zewnętrzne dachu blachodachówka', 64.18),
#  ('Robocizna - pokrycie zewnętrzne dachu blachodachówka', 119.52),
#  ('Robocizna - pokrycie zewnętrzne dachu dachówka ceramiczna', 48.87),
#  ('Robocizna - pokrycie zewnętrzne dachu dachówka ceramiczna', 70.47),
#  ('Robocizna - pokrycie zewnętrzne dachu dachówka ceramiczna', 128.57),
#  ('Lukarny', 2010.49),
#  ('Rynny - zakup + montaż PCV', 76.86),
#  ('Rynny - zakup + montaż PCV', 96.32),
#  ('Rynny - zakup + montaż PCV', 131.38),
#  ('Rynny - zakup + montaż stalowe', 137.91),
#  ('Rynny - zakup + montaż stalowe', 158.45),
#  ('Rynny - zakup + montaż stalowe', 204.84),
#  ('Okna dachowe (z montażem)', 1171.52),
#  ('Okna dachowe (z montażem)', 1664.98),
#  ('Okna dachowe (z montażem)', 2388.89),
#  ('Wyłaz dachowy z montażem', 456.52),
#  ('Wyłaz dachowy z montażem', 537.77),
#  ('Wyłaz dachowy z montażem', 651.86),
#  ('Materiały do docieplenia dachu ocieplenie dachu po stropie drewnianym lub po skosach poddasza użytkowego',
#   56.87),
#  ('Materiały do docieplenia dachu ocieplenie dachu po stropie drewnianym lub po skosach poddasza użytkowego',
#   72.4),
#  ('Materiały do docieplenia dachu ocieplenie dachu po stropie drewnianym lub po skosach poddasza użytkowego',
#   90.61),
#  ('Materiały do docieplenia dachu ocieplenie stropu żelbetonowego/teriva nad piętrem',
#   43.18),
#  ('Materiały do docieplenia dachu ocieplenie stropu żelbetonowego/teriva nad piętrem',
#   53.31),
#  ('Materiały do docieplenia dachu ocieplenie stropu żelbetonowego/teriva nad piętrem',
#   65.98),
#  ('Docieplenie dachu - robocizna ocieplenie dachu po stropie drewnianym lub po skosach poddasza użytkowego',
#   65.46),
#  ('Docieplenie dachu - robocizna ocieplenie dachu po stropie drewnianym lub po skosach poddasza użytkowego',
#   76.98),
#  ('Docieplenie dachu - robocizna ocieplenie dachu po stropie drewnianym lub po skosach poddasza użytkowego',
#   130.66),
#  ('Docieplenie dachu - robocizna ocieplenie stropu żelbetonowego/teriva nad piętrem',
#   21.8),
#  ('Docieplenie dachu - robocizna ocieplenie stropu żelbetonowego/teriva nad piętrem',
#   30.71),
#  ('Docieplenie dachu - robocizna ocieplenie stropu żelbetonowego/teriva nad piętrem',
#   57.29),
#  ('Podbitka okapu - wszystkie niezbędne materiały', 34.03),
#  ('Podbitka okapu - wszystkie niezbędne materiały', 43.22),
#  ('Podbitka okapu - wszystkie niezbędne materiały', 54.24),
#  ('Podbitka okapu - robocizna', 36.43),
#  ('Podbitka okapu - robocizna', 54.7),
#  ('Podbitka okapu - robocizna', 103.72),
#  ('Okna PCV - białe', 475.3),
#  ('Okna PCV - białe', 533.74),
#  ('Okna PCV - białe', 649.92),
#  ('Okna drewniane', 815.57),
#  ('Okna drewniane', 895.37),
#  ('Okna drewniane', 1226.37),
#  ('Montaż okien', 90.15),
#  ('Montaż okien', 118.1),
#  ('Montaż okien', 213.32),
#  ('Drzwi wejściowe (z montażem) stalowe', 2419.36),
#  ('Drzwi wejściowe (z montażem) stalowe', 3392.64),
#  ('Drzwi wejściowe (z montażem) stalowe', 5027.31),
#  ('Drzwi wejściowe (z montażem) drewniane', 1810.98),
#  ('Drzwi wejściowe (z montażem) drewniane', 2039.9),
#  ('Drzwi wejściowe (z montażem) drewniane', 2678.75),
#  ('Brama garażowa (z montażem) rozwierana', 1841.39),
#  ('Brama garażowa (z montażem) rozwierana', 2335.81),
#  ('Brama garażowa (z montażem) rozwierana', 3263.51),
#  ('Brama garażowa (z montażem) uchylna', 2284.37),
#  ('Brama garażowa (z montażem) uchylna', 2581.23),
#  ('Brama garażowa (z montażem) uchylna', 3812.45),
#  ('Posadzka w piwnicy (na gruncie) - materiały', 49.47),
#  ('Posadzka w piwnicy (na gruncie) - materiały', 59.39),
#  ('Posadzka w piwnicy (na gruncie) - materiały', 80.78),
#  ('Posadzka na parterze - materiały', 30.43),
#  ('Posadzka na parterze - materiały', 42.36),
#  ('Posadzka na parterze - materiały', 57.22),
#  ('Posadzka na piętrze - materiały', 30.43),
#  ('Posadzka na piętrze - materiały', 42.36),
#  ('Posadzka na piętrze - materiały', 57.22),
#  ('Wykonanie posadzek na wszystkich kondygnacjach', 16.73),
#  ('Wykonanie posadzek na wszystkich kondygnacjach', 22.93),
#  ('Wykonanie posadzek na wszystkich kondygnacjach', 47.05),
#  ('Tynkowanie - materiały gipsowe', 17.49),
#  ('Tynkowanie - materiały gipsowe', 19.77),
#  ('Tynkowanie - materiały gipsowe', 25.06),
#  ('Tynkowanie - materiały cementowo-wapienne', 20.41),
#  ('Tynkowanie - materiały cementowo-wapienne', 22.75),
#  ('Tynkowanie - materiały cementowo-wapienne', 26.48),
#  ('Tynkowanie - robocizna gipsowe', 19.06),
#  ('Tynkowanie - robocizna gipsowe', 25.1),
#  ('Tynkowanie - robocizna gipsowe', 31.89),
#  ('Tynkowanie - robocizna cementowo-wapienne', 17.74),
#  ('Tynkowanie - robocizna cementowo-wapienne', 25.0),
#  ('Tynkowanie - robocizna cementowo-wapienne', 31.11),
#  ('Gładź gipsowa',),
#  ('Robocizna - gipsowanie', 18.38),
#  ('Robocizna - gipsowanie', 24.35),
#  ('Robocizna - gipsowanie', 43.39),
#  ('Parapety wewnętrzne - zakup materiałów', 28.18),
#  ('Parapety wewnętrzne - zakup materiałów', 33.95),
#  ('Parapety wewnętrzne - zakup materiałów', 43.26),
#  ('Robocizna - montaż parapetów wewnętrznych', 51.91),
#  ('Robocizna - montaż parapetów wewnętrznych', 75.7),
#  ('Robocizna - montaż parapetów wewnętrznych', 155.69),
#  ('Parapety zewnętrzne - zakup materiałów', 33.77),
#  ('Parapety zewnętrzne - zakup materiałów', 41.29),
#  ('Parapety zewnętrzne - zakup materiałów', 57.47),
#  ('Robocizna - montaż parapetów zewnętrznych', 71.47),
#  ('Robocizna - montaż parapetów zewnętrznych', 107.33),
#  ('Robocizna - montaż parapetów zewnętrznych', 208.45),
#  ('Materiały + montaż instalacji elektrycznej NIE, podaj mi wyłącznie koszt materiałów',
#   37.45),
#  ('Materiały + montaż instalacji elektrycznej NIE, podaj mi wyłącznie koszt materiałów',
#   47.08),
#  ('Materiały + montaż instalacji elektrycznej NIE, podaj mi wyłącznie koszt materiałów',
#   82.78),
#  ('Materiały + montaż instalacji elektrycznej TAK, podaj mi łączny koszt materiałów i wykonania instalacji przez elektryka',
#   136.5),
#  ('Materiały + montaż instalacji elektrycznej TAK, podaj mi łączny koszt materiałów i wykonania instalacji przez elektryka',
#   157.49),
#  ('Materiały + montaż instalacji elektrycznej TAK, podaj mi łączny koszt materiałów i wykonania instalacji przez elektryka',
#   276.87),
#  ('Instalacja wodno-kanalizacyjna - montaż+materiały', 518.03),
#  ('Instalacja wodno-kanalizacyjna - montaż+materiały', 611.34),
#  ('Instalacja wodno-kanalizacyjna - montaż+materiały', 867.14),
#  ('Sufit podwieszany - materiały płyta karton-gips na ruszcie', 53.64),
#  ('Sufit podwieszany - materiały płyta karton-gips na ruszcie', 57.8),
#  ('Sufit podwieszany - materiały płyta karton-gips na ruszcie', 89.21),
#  ('Sufit podwieszany - materiały systemowy', 116.8),
#  ('Sufit podwieszany - materiały systemowy', 128.78),
#  ('Sufit podwieszany - materiały systemowy', 189.01),
#  ('Sufit podwieszany - montaż płyta karton-gips na ruszcie', 95.66),
#  ('Sufit podwieszany - montaż płyta karton-gips na ruszcie', 122.73),
#  ('Sufit podwieszany - montaż płyta karton-gips na ruszcie', 195.49),
#  ('Sufit podwieszany - montaż systemowy', 49.81),
#  ('Sufit podwieszany - montaż systemowy', 83.37),
#  ('Sufit podwieszany - montaż systemowy', 151.95),
#  ('Grzejniki + Instalacja C.O. - materiały + montaż', 114.91),
#  ('Grzejniki + Instalacja C.O. - materiały + montaż', 139.68),
#  ('Grzejniki + Instalacja C.O. - materiały + montaż', 199.5),
#  ('Ogrzewanie podłogowe - materiały + robocizna', 126.69),
#  ('Ogrzewanie podłogowe - materiały + robocizna', 153.36),
#  ('Ogrzewanie podłogowe - materiały + robocizna', 220.0),
#  ('Wyposażenie kotłowni - osprzęt i materiały kocioł gazowy', 11632.38),
#  ('Wyposażenie kotłowni - osprzęt i materiały kocioł gazowy', 20347.43),
#  ('Wyposażenie kotłowni - osprzęt i materiały kocioł gazowy', 33631.57),
#  ('Wyposażenie kotłowni - osprzęt i materiały kocioł na paliwo stałe',
#   11997.08),
#  ('Wyposażenie kotłowni - osprzęt i materiały kocioł na paliwo stałe',
#   17579.39),
#  ('Wyposażenie kotłowni - osprzęt i materiały kocioł na paliwo stałe',
#   24023.07),
#  ('Wyposażenie kotłowni - montaż, robocizna',),
#  ('Zestaw ogrzewania podłogowego z programowalnym regulatorem temperatury TVT 04 ED',),
#  ('Fundamenty - potrzebne materiały', 194.4),
#  ('Fundamenty - potrzebne materiały', 259.22),
#  ('Fundamenty - potrzebne materiały', 379.28),
#  ('Robocizna - wykonanie fundamentów', 93.51),
#  ('Robocizna - wykonanie fundamentów', 97.85),
#  ('Robocizna - wykonanie fundamentów', 131.99),
#  ('Ściany nośne - materiały beton komórkowy Ytong Energo+ 36,5 cm', 108.68),
#  ('Ściany nośne - materiały beton komórkowy Ytong Energo+ 36,5 cm', 123.0),
#  ('Ściany nośne - materiały beton komórkowy Ytong Energo+ 36,5 cm', 178.34),
#  ('Ściany nośne - materiały beton komórkowy H+H 24', 46.14),
#  ('Ściany nośne - materiały beton komórkowy H+H 24', 64.44),
#  ('Ściany nośne - materiały beton komórkowy H+H 24', 91.06),
#  ('Wykonanie ścian nośnych - robocizna beton komórkowy Ytong Energo+ 36,5 cm',
#   46.55),
#  ('Wykonanie ścian nośnych - robocizna beton komórkowy Ytong Energo+ 36,5 cm',
#   66.62),
#  ('Wykonanie ścian nośnych - robocizna beton komórkowy Ytong Energo+ 36,5 cm',
#   118.75),
#  ('Wykonanie ścian nośnych - robocizna beton komórkowy', 43.72),
#  ('Wykonanie ścian nośnych - robocizna beton komórkowy', 63.99),
#  ('Wykonanie ścian nośnych - robocizna beton komórkowy', 116.35),
#  ('Materiały - ściany działowe ceramiczne - Porotherm', 37.3),
#  ('Materiały - ściany działowe ceramiczne - Porotherm', 44.79),
#  ('Materiały - ściany działowe ceramiczne - Porotherm', 68.95),
#  ('Materiały - ściany działowe beton komórkowy', 25.66),
#  ('Materiały - ściany działowe beton komórkowy', 31.76),
#  ('Materiały - ściany działowe beton komórkowy', 38.71),
#  ('Robocizna - wykonanie ścian działowych ceramiczne', 29.16),
#  ('Robocizna - wykonanie ścian działowych ceramiczne', 39.3),
#  ('Robocizna - wykonanie ścian działowych ceramiczne', 63.39),
#  ('Robocizna - wykonanie ścian działowych beton komórkowy', 34.13),
#  ('Robocizna - wykonanie ścian działowych beton komórkowy', 36.65),
#  ('Robocizna - wykonanie ścian działowych beton komórkowy', 66.29),
#  ('Kominy wentylacyjne + szachty', 256.18),
#  ('Kominy wentylacyjne + szachty', 323.29),
#  ('Kominy wentylacyjne + szachty', 474.83),
#  ('Kominy dymowe', 3889.02),
#  ('Kominy dymowe', 4273.25),
#  ('Kominy dymowe', 4866.62),
#  ('Wykończenie kominów', 1130.55),
#  ('Wykończenie kominów', 1706.0),
#  ('Wykończenie kominów', 3093.53),
#  ('Materiały do wykonania stropu drewniany', 279.53),
#  ('Materiały do wykonania stropu drewniany', 323.3),
#  ('Materiały do wykonania stropu drewniany', 400.28),
#  ('Materiały do wykonania stropu prefabrykowany teriva', 377.31),
#  ('Materiały do wykonania stropu prefabrykowany teriva', 415.53),
#  ('Materiały do wykonania stropu prefabrykowany teriva', 478.27),
#  ('Robocizna - wykonanie stropu drewniany', 28.82),
#  ('Robocizna - wykonanie stropu drewniany', 44.02),
#  ('Robocizna - wykonanie stropu drewniany', 81.4),
#  ('Robocizna - wykonanie stropu prefabrykowany teriva', 43.98),
#  ('Robocizna - wykonanie stropu prefabrykowany teriva', 61.82),
#  ('Robocizna - wykonanie stropu prefabrykowany teriva', 121.08),
#  ('Elewacja - materiały styropian', 105.94),
#  ('Elewacja - materiały styropian', 131.73),
#  ('Elewacja - materiały styropian', 161.6),
#  ('Elewacja - materiały wełna mineralna', 142.64),
#  ('Elewacja - materiały wełna mineralna', 177.52),
#  ('Elewacja - materiały wełna mineralna', 209.63),
#  ('Elewacja - robocizna styropian', 71.29),
#  ('Elewacja - robocizna styropian', 83.38),
#  ('Elewacja - robocizna styropian', 103.71),
#  ('Elewacja - robocizna wełna mineralna', 81.7),
#  ('Elewacja - robocizna wełna mineralna', 92.3),
#  ('Elewacja - robocizna wełna mineralna', 113.19),
#  ('Więźba dachowa - materiały', 61.22),
#  ('Więźba dachowa - materiały', 75.56),
#  ('Więźba dachowa - materiały', 112.61),
#  ('Robocizna - wykonanie więźby dachowej', 31.65),
#  ('Robocizna - wykonanie więźby dachowej', 46.29),
#  ('Robocizna - wykonanie więźby dachowej', 78.42),
#  ('Poszycie dachu - materiały membrana', 3.82),
#  ('Poszycie dachu - materiały membrana', 4.39),
#  ('Poszycie dachu - materiały membrana', 5.45),
#  ('Poszycie dachu - materiały papa na deskowaniu', 39.72),
#  ('Poszycie dachu - materiały papa na deskowaniu', 49.45),
#  ('Poszycie dachu - materiały papa na deskowaniu', 69.18),
#  ('Robocizna - wykonanie poszycia dachu membrana', 8.7),
#  ('Robocizna - wykonanie poszycia dachu membrana', 12.92),
#  ('Robocizna - wykonanie poszycia dachu membrana', 23.0),
#  ('Robocizna - wykonanie poszycia dachu papa na deskowaniu', 19.97),
#  ('Robocizna - wykonanie poszycia dachu papa na deskowaniu', 29.66),
#  ('Robocizna - wykonanie poszycia dachu papa na deskowaniu', 47.89),
#  ('Pokrycie zewnętrzne dachu - materiały blachodachówka', 51.4),
#  ('Pokrycie zewnętrzne dachu - materiały blachodachówka', 58.02),
#  ('Pokrycie zewnętrzne dachu - materiały blachodachówka', 73.26),
#  ('Pokrycie zewnętrzne dachu - materiały dachówka ceramiczna', 69.34),
#  ('Pokrycie zewnętrzne dachu - materiały dachówka ceramiczna', 87.21),
#  ('Pokrycie zewnętrzne dachu - materiały dachówka ceramiczna', 103.63),
#  ('Robocizna - pokrycie zewnętrzne dachu blachodachówka', 43.32),
#  ('Robocizna - pokrycie zewnętrzne dachu blachodachówka', 64.18),
#  ('Robocizna - pokrycie zewnętrzne dachu blachodachówka', 119.52),
#  ('Robocizna - pokrycie zewnętrzne dachu dachówka ceramiczna', 48.87),
#  ('Robocizna - pokrycie zewnętrzne dachu dachówka ceramiczna', 70.47),
#  ('Robocizna - pokrycie zewnętrzne dachu dachówka ceramiczna', 128.57),
#  ('Lukarny', 2010.49),
#  ('Rynny - zakup + montaż PCV', 76.86),
#  ('Rynny - zakup + montaż PCV', 96.32),
#  ('Rynny - zakup + montaż PCV', 131.38),
#  ('Rynny - zakup + montaż stalowe', 137.91),
#  ('Rynny - zakup + montaż stalowe', 158.45),
#  ('Rynny - zakup + montaż stalowe', 204.84),
#  ('Okna dachowe + montaż', 1171.52),
#  ('Okna dachowe + montaż', 1664.98),
#  ('Okna dachowe + montaż', 2388.89),
#  ('Wyłaz dachowy', 456.52),
#  ('Wyłaz dachowy', 537.77),
#  ('Wyłaz dachowy', 651.86),
#  ('Materiały do docieplenia stropu drewniany', 56.87),
#  ('Materiały do docieplenia stropu drewniany', 72.4),
#  ('Materiały do docieplenia stropu drewniany', 90.61),
#  ('Materiały do docieplenia stropu żelbetonowy/teriva', 43.18),
#  ('Materiały do docieplenia stropu żelbetonowy/teriva', 53.31),
#  ('Materiały do docieplenia stropu żelbetonowy/teriva', 65.98),
#  ('Docieplenie stropu - robocizna drewniany', 65.46),
#  ('Docieplenie stropu - robocizna drewniany', 76.98),
#  ('Docieplenie stropu - robocizna drewniany', 130.66),
#  ('Docieplenie stropu - robocizna żelbetonowy/teriva', 21.8),
#  ('Docieplenie stropu - robocizna żelbetonowy/teriva', 30.71),
#  ('Docieplenie stropu - robocizna żelbetonowy/teriva', 57.29),
#  ('Podbitka okapu - materiały', 34.03),
#  ('Podbitka okapu - materiały', 43.22),
#  ('Podbitka okapu - materiały', 54.24),
#  ('Podbitka okapu - robocizna', 36.43),
#  ('Podbitka okapu - robocizna', 54.7),
#  ('Podbitka okapu - robocizna', 103.72),
#  ('Okna PCV - białe', 458.02),
#  ('Okna PCV - białe', 498.77),
#  ('Okna PCV - białe', 610.6),
#  ('Okna drewniane', 700.82),
#  ('Okna drewniane', 826.91),
#  ('Okna drewniane', 1068.41),
#  ('Montaż okien', 90.15),
#  ('Montaż okien', 118.1),
#  ('Montaż okien', 213.32),
#  ('Drzwi wejściowe (z montażem) stalowe', 2419.36),
#  ('Drzwi wejściowe (z montażem) stalowe', 3392.64),
#  ('Drzwi wejściowe (z montażem) stalowe', 5027.31),
#  ('Drzwi wejściowe (z montażem) drewniane', 1810.98),
#  ('Drzwi wejściowe (z montażem) drewniane', 2039.9),
#  ('Drzwi wejściowe (z montażem) drewniane', 2678.75),
#  ('Brama garażowa (z montażem) rozwierana', 1841.39),
#  ('Brama garażowa (z montażem) rozwierana', 2335.81),
#  ('Brama garażowa (z montażem) rozwierana', 3263.51),
#  ('Brama garażowa (z montażem) uchylna', 2284.37),
#  ('Brama garażowa (z montażem) uchylna', 2581.23),
#  ('Brama garażowa (z montażem) uchylna', 3812.45),
#  ('Posadzka na gruncie - materiały', 49.47),
#  ('Posadzka na gruncie - materiały', 59.39),
#  ('Posadzka na gruncie - materiały', 80.78),
#  ('Robocizna - wykonanie posadzki', 16.73),
#  ('Robocizna - wykonanie posadzki', 22.93),
#  ('Robocizna - wykonanie posadzki', 47.05),
#  ('Tynkowanie - materiały gipsowy', 17.49),
#  ('Tynkowanie - materiały gipsowy', 19.77),
#  ('Tynkowanie - materiały gipsowy', 25.06),
#  ('Tynkowanie - materiały cementowo-wapienny', 20.41),
#  ('Tynkowanie - materiały cementowo-wapienny', 22.75),
#  ('Tynkowanie - materiały cementowo-wapienny', 26.48),
#  ('Tynkowanie - robocizna gipsowy', 19.06),
#  ('Tynkowanie - robocizna gipsowy', 25.1),
#  ('Tynkowanie - robocizna gipsowy', 31.89),
#  ('Tynkowanie - robocizna cementowo-wapienny', 17.74),
#  ('Tynkowanie - robocizna cementowo-wapienny', 25.0),
#  ('Tynkowanie - robocizna cementowo-wapienny', 31.11),
#  ('Gładź gipsowa',),
#  ('Robocizna - gipsowanie', 18.38),
#  ('Robocizna - gipsowanie', 24.35),
#  ('Robocizna - gipsowanie', 43.39),
#  ('Parapety wewnętrzne', 28.18),
#  ('Parapety wewnętrzne', 33.95),
#  ('Parapety wewnętrzne', 43.26),
#  ('Robocizna - montaż parapetów wewnętrznych', 51.91),
#  ('Robocizna - montaż parapetów wewnętrznych', 75.7),
#  ('Robocizna - montaż parapetów wewnętrznych', 155.69),
#  ('Parapety zewnętrzne', 33.77),
#  ('Parapety zewnętrzne', 41.29),
#  ('Parapety zewnętrzne', 57.47),
#  ('Robocizna - montaż parapetów zewnętrznych', 71.47),
#  ('Robocizna - montaż parapetów zewnętrznych', 107.33),
#  ('Robocizna - montaż parapetów zewnętrznych', 208.45),
#  ('Materiały + montaż instalacji elektrycznej NIE, podaj tylko koszt materiałów',
#   37.45),
#  ('Materiały + montaż instalacji elektrycznej NIE, podaj tylko koszt materiałów',
#   47.08),
#  ('Materiały + montaż instalacji elektrycznej NIE, podaj tylko koszt materiałów',
#   82.78),
#  ('Materiały + montaż instalacji elektrycznej TAK, podaj koszt materiałów i robocizny',
#   136.5),
#  ('Materiały + montaż instalacji elektrycznej TAK, podaj koszt materiałów i robocizny',
#   157.49),
#  ('Materiały + montaż instalacji elektrycznej TAK, podaj koszt materiałów i robocizny',
#   276.87),
#  ('Instalacja wodno-kanalizacyjna - montaż+materiały', 518.03),
#  ('Instalacja wodno-kanalizacyjna - montaż+materiały', 611.34),
#  ('Instalacja wodno-kanalizacyjna - montaż+materiały', 867.14),
#  ('Sufit podwieszany - materiały płyta karton-gips na ruszcie', 53.64),
#  ('Sufit podwieszany - materiały płyta karton-gips na ruszcie', 57.8),
#  ('Sufit podwieszany - materiały płyta karton-gips na ruszcie', 89.21),
#  ('Sufit podwieszany - materiały systemowy', 116.8),
#  ('Sufit podwieszany - materiały systemowy', 128.78),
#  ('Sufit podwieszany - materiały systemowy', 189.01),
#  ('Sufit podwieszany - montaż płyta karton-gips na ruszcie', 95.66),
#  ('Sufit podwieszany - montaż płyta karton-gips na ruszcie', 122.73),
#  ('Sufit podwieszany - montaż płyta karton-gips na ruszcie', 195.49),
#  ('Sufit podwieszany - montaż systemowy', 49.81),
#  ('Sufit podwieszany - montaż systemowy', 83.37),
#  ('Sufit podwieszany - montaż systemowy', 151.95),
#  ('Grzejniki + Instalacja C.O. - materiały + montaż', 114.91),
#  ('Grzejniki + Instalacja C.O. - materiały + montaż', 139.68),
#  ('Grzejniki + Instalacja C.O. - materiały + montaż', 199.5),
#  ('Ogrzewanie podłogowe - materiały + robocizna', 126.69),
#  ('Ogrzewanie podłogowe - materiały + robocizna', 153.36),
#  ('Ogrzewanie podłogowe - materiały + robocizna', 220.0),
#  ('Wyposażenie kotłowni - osprzęt i materiały gazowy', 11632.38),
#  ('Wyposażenie kotłowni - osprzęt i materiały gazowy', 20347.43),
#  ('Wyposażenie kotłowni - osprzęt i materiały gazowy', 33631.57),
#  ('Wyposażenie kotłowni - osprzęt i materiały na paliwo stałe', 11997.08),
#  ('Wyposażenie kotłowni - osprzęt i materiały na paliwo stałe', 17579.39),
#  ('Wyposażenie kotłowni - osprzęt i materiały na paliwo stałe', 24023.07),
#  ('Wyposażenie kotłowni - montaż, robocizna',),
#  ('Zestaw ogrzewania podłogowego z programowalnym regulatorem temperatury TVT 04 ED',),
#  ('Fundamenty i konstrukcja nośna - materiały', 256.46),
#  ('Fundamenty i konstrukcja nośna - materiały', 290.19),
#  ('Fundamenty i konstrukcja nośna - materiały', 390.22),
#  ('Nawierzchnia tarasu - materiały deska sosnowa tarasowa', 86.43),
#  ('Nawierzchnia tarasu - materiały deska sosnowa tarasowa', 96.92),
#  ('Nawierzchnia tarasu - materiały deska sosnowa tarasowa', 116.15),
#  ('Nawierzchnia tarasu - materiały deska tarasowa - konglomerat', 375.14),
#  ('Nawierzchnia tarasu - materiały deska tarasowa - konglomerat', 448.57),
#  ('Nawierzchnia tarasu - materiały deska tarasowa - konglomerat', 502.48),
#  ('Schody na taras prefabryowane', 2882.88),
#  ('Robocizna - komplet prac przy tarasie', 320.36),
#  ('Robocizna - komplet prac przy tarasie', 443.24),
#  ('Robocizna - komplet prac przy tarasie', 866.6),
#  ('Materiały na ogrodzenie ozdobne stalowe z bloczków betonowych', 598.29),
#  ('Materiały na ogrodzenie ozdobne stalowe z bloczków betonowych', 670.91),
#  ('Materiały na ogrodzenie ozdobne stalowe z bloczków betonowych', 804.01),
#  ('Materiały na ogrodzenie ozdobne stalowe z klinkieru', 671.19),
#  ('Materiały na ogrodzenie ozdobne stalowe z klinkieru', 801.32),
#  ('Materiały na ogrodzenie ozdobne stalowe z klinkieru', 897.61),
#  ('Robocizna - wykonanie ogrodzenia ozdobnego stalowego z bloczków betonowych',
#   499.92),
#  ('Robocizna - wykonanie ogrodzenia ozdobnego stalowego z bloczków betonowych',
#   697.77),
#  ('Robocizna - wykonanie ogrodzenia ozdobnego stalowego z bloczków betonowych',
#   1368.29),
#  ('Robocizna - wykonanie ogrodzenia ozdobnego stalowego z klinkieru', 397.1),
#  ('Robocizna - wykonanie ogrodzenia ozdobnego stalowego z klinkieru', 559.16),
#  ('Robocizna - wykonanie ogrodzenia ozdobnego stalowego z klinkieru', 1095.8),
#  ('Brama - materiały rozwierana', 199.92),
#  ('Brama - materiały rozwierana', 291.97),
#  ('Brama - materiały rozwierana', 571.54),
#  ('Brama - materiały przesuwna', 401.08),
#  ('Brama - materiały przesuwna', 479.57),
#  ('Brama - materiały przesuwna', 537.22),
#  ('Brama - wykonanie i montaż rozwierna', 661.78),
#  ('Brama - wykonanie i montaż rozwierna', 753.27),
#  ('Brama - wykonanie i montaż rozwierna', 918.33),
#  ('Brama - wykonanie i montaż przesuwna', 253.62),
#  ('Brama - wykonanie i montaż przesuwna', 379.3),
#  ('Brama - wykonanie i montaż przesuwna', 754.87),
#  ('Napęd do bramy (z montażem)',),
#  ('Furtka - materiały', 175.2),
#  ('Furtka - materiały', 282.71),
#  ('Furtka - materiały', 630.12),
#  ('Furtka - wykonanie + montaż', 905.8),
#  ('Furtka - wykonanie + montaż', 1038.7),
#  ('Furtka - wykonanie + montaż', 1262.19),
#  ('Materiały na ogrodzenie z siatki', 164.71),
#  ('Materiały na ogrodzenie z siatki', 186.39),
#  ('Materiały na ogrodzenie z siatki', 250.63),
#  ('Robocizna - wykonanie ogrodzenia z siatki', 126.92),
#  ('Robocizna - wykonanie ogrodzenia z siatki', 175.6),
#  ('Robocizna - wykonanie ogrodzenia z siatki', 343.31),
#  ('Wykonanie nawierzchni utwardzanej - materiały', 84.61),
#  ('Wykonanie nawierzchni utwardzanej - materiały', 102.66),
#  ('Wykonanie nawierzchni utwardzanej - materiały', 207.28),
#  ('Robocizna - wykonanie nawierzchni utwardzonej', 48.02),
#  ('Robocizna - wykonanie nawierzchni utwardzonej', 59.22),
#  ('Robocizna - wykonanie nawierzchni utwardzonej', 88.57),
#  ('Basen ogrodowy z montażem Basen przenośny', 165.9),
#  ('Basen ogrodowy z montażem Basen przenośny', 695.49),
#  ('Basen ogrodowy z montażem Basen przenośny', 1808.64),
#  ('Basen ogrodowy z montażem Basen poliestrowy do wkopania w ziemię',
#   17466.68),
#  ('Basen ogrodowy z montażem Basen poliestrowy do wkopania w ziemię', 33566.4),
#  ('Basen ogrodowy z montażem Basen poliestrowy do wkopania w ziemię',
#   102547.5),
#  ('Zakup szamba betonowe', 1595.16),
#  ('Zakup szamba betonowe', 3863.83),
#  ('Zakup szamba betonowe', 5331.92),
#  ('Zakup szamba plastikowe', 3119.05),
#  ('Zakup szamba plastikowe', 8055.94),
#  ('Zakup szamba plastikowe', 10254.75),
#  ('Transport i montaż szamba',)]

# %% [markdown]
# It runs relatively long (~15 minutes), but not to flood the server with too many requests at once I used a respectful wait period between each request (10 - 20 seconds) - still beats doing it manually.
#
# I run this script monthly in order to build a better understanding on how the prices in the polish construction sector develop over time (reasons).
